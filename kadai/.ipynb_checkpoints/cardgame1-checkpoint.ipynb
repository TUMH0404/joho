# %% [markdown]
# ## ババ抜きをしようとすると，どんな手続きをしますか？？？

# %% [markdown]
# > 1.トランプを用意する，ババを1枚入れる<br>
# > 2.誰かがトランプをきる<br>
# > 3.切ったトランプを人数分配る<br>
# > 4.数字がペアになっているカードを捨てる<br>
# > 5.ゲームを開始する<br>
# > 6.カードを引いり，渡したり，ペアになったカードを捨てたり・・・<br>
# > 7.手元にカードがなくなった順に終了<br>

# %% [markdown]
# 1. トランプを用意しよう！！

# %% [markdown]
# **トランプのセットを作る。** <br>
# - cardという空リストを作る。<br>
# - spadeの組を作り，それをcardに格納する。<br>
# - heartの組を作り，それをcardに格納する。<br>
# - diamondの組を作り，それをcardに格納する。<br>
# - diamondの組を作り，それをcardに格納する。<br>
# - Jokerを格納する。<br>
# - トランプなのでバラバラにしたい。<br>
# $\cdots$<br>
# $\cdots$<br>
# $\cdots$<br>
#
# ```
# import random
# ```
# というライブラリを追加する。

# %% [markdown]
# ## 下準備

# %%
## 必要なライブラリをインポートする
#########################
import random
# 以上 #

#########################
def cardset(joka=0):
    '''
    トランプカードを作って混ぜる。
    jokaでジョーカーの枚数を指定する
    '''
# 格納する空リスト
    card = []
## トランプカードの種類
# マーク
    mark =["spade","heart","diamond","club"]
# 数
    num = ["A","K","Q","J","X","9","8","7","6","5","4","3","2"]
# ジョーカー
    Joker = ["j1","j2"]

# それぞれ組み合わせる
    for i in mark:
        for k in num:
            card.append(f"{k}_{i}")

# ジョーカーを追加する
    if joka==1 or joka==2:
        card.append(Joker[joka-1])
    else:
        pass

# 混ぜる
    for i in range(5):
        random.shuffle(card)
        
    return card
# 以上 #


#########################
def dealcard(Gcard,N):
    '''
    トランプを配る。
    Gcard:トランプ
    N:配られる人数もしくは，リストに納められた文字型の名前
    '''
    cc = {}
    if isinstance(N,int):
        NN = N
        for u in range(N):
            cc.update({f"p{u}":[]})
    
    elif isinstance(N,list):
        NN = len(N)
        random.shuffle(N)
        for u in N:
            cc.update({str(u):[]})
    
    else:
        NN = 4
        for u in range(4):
            cc.update({f"p{u}":[]})
    
    
    p = list(cc.keys())

    maisuu = int(len(Gcard)//NN)# 配る枚数
    nokori = len(Gcard)%NN      # 残り

    for kubaru in range(maisuu):
        #random.shuffle(p)
        a = random.sample(Gcard,NN)
        for i,k in zip(p,a):
            cc[i].append(k)
            Gcard.remove(k) 

    ## 残りのカード誰に配る？
    morauhito = random.sample(p,nokori)
    for u,y in zip(morauhito,Gcard):
        cc[u].append(y)
    
    return cc
# 以上 #

#################################
def baba3(A):
    '''
    配られたカードを整理する
    '''
    c2 = A[:] ## 深いコピー
    ## 並べ替え
    c2.sort()
    ## 数字を取り出す
    c0 = [i[0] for i in c2]
    # 集合してリスト化する
    c1 = list(set(c0))
    # ソートする
    c1.sort()
    
    # 一枚もののカードを格納する空リストを作る。
    single =[]
    
    # 数字を回して検索する
    for i in c1:
        # 念の為ソートする
        c2.sort()
        
        # 同じものが複数ある時の処理。
        # 一枚になれば，singleに追加する。
        gg0 = c0.count(i)//2
        gg1 = c0.count(i)%2
        if gg0==1 and gg1 == 0:  # 偶数だけ捨てる
            del c2[:2]
            
        elif gg0==2 and gg1==0:   # 偶数だけ捨てる
            del c2[:4]
            
        elif gg0==1 and gg1==1:
            del c2[:2]
            single.append(c2[0]) #組み合わせがないカードだけを格納
            del c2[0]
            
        elif gg0==0 and gg1 ==1:
            single.append(c2[0])  #組み合わせがないカードだけを格納
            del c2[0]
            
    return single
# 以上 #


###################
def pickup(me,you):
    '''
    カードの受け渡し
    me:取る人
    you:取られる人
    '''
    
    random.shuffle(you)             # youはカードを混ぜる
    if len(you)==0:
        print("youの長さがゼロです")
        
        return 0,0
    
    
    else:
        a = list(range(len(you))) 
        ii = random.sample(a,1)[0] # 好きなカードを選ぶ 
    
        me.append(you[ii])         # とったカードと手元のカードを合わせる
        del you[ii]                # カードを渡す
        
        return baba3(me),you       # 結果
# 以上 #

# %%
s = cardset(joka=1)
s.sort()
s
# Out:
# ['2_club',
#  '2_diamond',
#  '2_heart',
#  '2_spade',
#  '3_club',
#  '3_diamond',
#  '3_heart',
#  '3_spade',
#  '4_club',
#  '4_diamond',
#  '4_heart',
#  '4_spade',
#  '5_club',
#  '5_diamond',
#  '5_heart',
#  '5_spade',
#  '6_club',
#  '6_diamond',
#  '6_heart',
#  '6_spade',
#  '7_club',
#  '7_diamond',
#  '7_heart',
#  '7_spade',
#  '8_club',
#  '8_diamond',
#  '8_heart',
#  '8_spade',
#  '9_club',
#  '9_diamond',
#  '9_heart',
#  '9_spade',
#  'A_club',
#  'A_diamond',
#  'A_heart',
#  'A_spade',
#  'J_club',
#  'J_diamond',
#  'J_heart',
#  'J_spade',
#  'K_club',
#  'K_diamond',
#  'K_heart',
#  'K_spade',
#  'Q_club',
#  'Q_diamond',
#  'Q_heart',
#  'Q_spade',
#  'X_club',
#  'X_diamond',
#  'X_heart',
#  'X_spade',
#  'j1']

# %% [markdown]
# ## 実行セル

# %%
## ババ抜きしてみよう ##
## 実行するためのセル  ##
mm = ["tomo","kobay","takami","shinohara"]
random.shuffle(mm)
cc =dealcard(cardset(joka=1),mm)
## カードを整理する(揃う数字を取り除いく) ##
for i in cc:
    cc[i] = baba3(cc[i])

## その中身を確認する ##   
print(cc)


## いよいよゲーム開始! ##
## 一瞬で終わるので見逃さないように ##
## 誰が勝つでしょう？？  ##
goal = []
times = 0
pp=cc.copy()
while 1:
    menbers = list(pp.keys())
    for ite,i in enumerate(menbers):
        if ite+1 == len(menbers):
            me = menbers[ite]
            you = menbers[0]

        else:
            me = menbers[ite]
            you =menbers[ite+1]
        
        if len(pp[me])==0:
            continue
    
        else:
            A,B = pickup(pp[me],pp[you])
            if A!=0 and B!=0:
                pp[me] = A
                pp[you] = B
            
            else:
                continue
        print(pp)
    

    for u in list(pp.keys()):
        if len(pp[u])==0:
            goal.append(u)
            del pp[u]
        
        else:
            continue
    
    #print(f"test:{len(pp)}")
    times+=1
    
    if len(pp)==1:
        goal.extend(list(pp.keys()))
        print(goal)
        break

## 結果の表示 ##
print("\n"*2)
print(f"{times}回")
print("\n"*2)
print("順位")
for y,i in enumerate(goal):
    print(f"第{y+1}位:{i}")
# Out:
# {'shinohara': ['2_spade', '4_spade', 'A_club', 'J_spade', 'K_club'], 'tomo': ['2_diamond', '3_diamond', '4_heart', '5_spade', '6_diamond', '7_club', '9_club', 'A_diamond', 'J_heart', 'K_diamond', 'Q_spade', 'j1'], 'takami': ['2_club', '4_diamond', '6_heart', 'A_spade', 'X_diamond'], 'kobay': ['2_heart', '3_spade', '4_club', '5_heart', '7_diamond', '9_spade', 'A_heart', 'Q_heart', 'X_club']}
# {'shinohara': ['2_spade', '4_spade', '6_diamond', 'A_club', 'J_spade', 'K_club'], 'tomo': ['9_club', 'K_diamond', '4_heart', '3_diamond', 'j1', 'J_heart', '5_spade', '7_club', 'A_diamond', 'Q_spade', '2_diamond'], 'takami': ['2_club', '4_diamond', '6_heart', 'A_spade', 'X_diamond'], 'kobay': ['2_heart', '3_spade', '4_club', '5_heart', '7_diamond', '9_spade', 'A_heart', 'Q_heart', 'X_club']}
# {'shinohara': ['2_spade', '4_spade', '6_diamond', 'A_club', 'J_spade', 'K_club'], 'tomo': ['2_diamond', '3_diamond', '4_heart', '5_spade', '7_club', '9_club', 'J_heart', 'K_diamond', 'Q_spade', 'j1'], 'takami': ['6_heart', '4_diamond', '2_club', 'X_diamond'], 'kobay': ['2_heart', '3_spade', '4_club', '5_heart', '7_diamond', '9_spade', 'A_heart', 'Q_heart', 'X_club']}
# {'shinohara': ['2_spade', '4_spade', '6_diamond', 'A_club', 'J_spade', 'K_club'], 'tomo': ['2_diamond', '3_diamond', '4_heart', '5_spade', '7_club', '9_club', 'J_heart', 'K_diamond', 'Q_spade', 'j1'], 'takami': ['2_club', '4_diamond', '6_heart'], 'kobay': ['3_spade', '9_spade', 'Q_heart', '5_heart', '2_heart', '4_club', 'A_heart', '7_diamond']}
# {'shinohara': ['K_club', '6_diamond', 'J_spade', '2_spade', 'A_club'], 'tomo': ['2_diamond', '3_diamond', '4_heart', '5_spade', '7_club', '9_club', 'J_heart', 'K_diamond', 'Q_spade', 'j1'], 'takami': ['2_club', '4_diamond', '6_heart'], 'kobay': ['2_heart', '3_spade', '5_heart', '7_diamond', '9_spade', 'A_heart', 'Q_heart']}
# {'shinohara': ['2_spade', '6_diamond', '7_club', 'A_club', 'J_spade', 'K_club'], 'tomo': ['K_diamond', '5_spade', '4_heart', '2_diamond', 'J_heart', '3_diamond', 'Q_spade', '9_club', 'j1'], 'takami': ['2_club', '4_diamond', '6_heart'], 'kobay': ['2_heart', '3_spade', '5_heart', '7_diamond', '9_spade', 'A_heart', 'Q_heart']}
# {'shinohara': ['2_spade', '6_diamond', '7_club', 'A_club', 'J_spade', 'K_club'], 'tomo': ['2_diamond', '3_diamond', '5_spade', '9_club', 'J_heart', 'K_diamond', 'Q_spade', 'j1'], 'takami': ['2_club', '6_heart'], 'kobay': ['2_heart', '3_spade', '5_heart', '7_diamond', '9_spade', 'A_heart', 'Q_heart']}
# {'shinohara': ['2_spade', '6_diamond', '7_club', 'A_club', 'J_spade', 'K_club'], 'tomo': ['2_diamond', '3_diamond', '5_spade', '9_club', 'J_heart', 'K_diamond', 'Q_spade', 'j1'], 'takami': ['2_club', '6_heart', '7_diamond'], 'kobay': ['5_heart', '2_heart', 'Q_heart', '3_spade', '9_spade', 'A_heart']}
# {'shinohara': ['2_spade', 'A_club', '7_club', '6_diamond', 'J_spade'], 'tomo': ['2_diamond', '3_diamond', '5_spade', '9_club', 'J_heart', 'K_diamond', 'Q_spade', 'j1'], 'takami': ['2_club', '6_heart', '7_diamond'], 'kobay': ['2_heart', '3_spade', '5_heart', '9_spade', 'A_heart', 'K_club', 'Q_heart']}
# {'shinohara': ['2_spade', '6_diamond', '7_club', 'A_club'], 'tomo': ['9_club', '2_diamond', 'Q_spade', 'K_diamond', '5_spade', '3_diamond', 'j1'], 'takami': ['2_club', '6_heart', '7_diamond'], 'kobay': ['2_heart', '3_spade', '5_heart', '9_spade', 'A_heart', 'K_club', 'Q_heart']}
# {'shinohara': ['2_spade', '6_diamond', '7_club', 'A_club'], 'tomo': ['3_diamond', '5_spade', '9_club', 'K_diamond', 'Q_spade', 'j1'], 'takami': ['7_diamond', '6_heart'], 'kobay': ['2_heart', '3_spade', '5_heart', '9_spade', 'A_heart', 'K_club', 'Q_heart']}
# {'shinohara': ['2_spade', '6_diamond', '7_club', 'A_club'], 'tomo': ['3_diamond', '5_spade', '9_club', 'K_diamond', 'Q_spade', 'j1'], 'takami': ['2_heart', '6_heart', '7_diamond'], 'kobay': ['9_spade', 'Q_heart', 'A_heart', 'K_club', '3_spade', '5_heart']}
# {'shinohara': ['7_club', 'A_club', '6_diamond'], 'tomo': ['3_diamond', '5_spade', '9_club', 'K_diamond', 'Q_spade', 'j1'], 'takami': ['2_heart', '6_heart', '7_diamond'], 'kobay': ['2_spade', '3_spade', '5_heart', '9_spade', 'A_heart', 'K_club', 'Q_heart']}
# {'shinohara': ['6_diamond', '7_club', '9_club', 'A_club'], 'tomo': ['j1', 'K_diamond', 'Q_spade', '5_spade', '3_diamond'], 'takami': ['2_heart', '6_heart', '7_diamond'], 'kobay': ['2_spade', '3_spade', '5_heart', '9_spade', 'A_heart', 'K_club', 'Q_heart']}
# {'shinohara': ['6_diamond', '7_club', '9_club', 'A_club'], 'tomo': ['3_diamond', '5_spade', '6_heart', 'K_diamond', 'Q_spade', 'j1'], 'takami': ['2_heart', '7_diamond'], 'kobay': ['2_spade', '3_spade', '5_heart', '9_spade', 'A_heart', 'K_club', 'Q_heart']}
# {'shinohara': ['6_diamond', '7_club', '9_club', 'A_club'], 'tomo': ['3_diamond', '5_spade', '6_heart', 'K_diamond', 'Q_spade', 'j1'], 'takami': ['7_diamond'], 'kobay': ['K_club', 'A_heart', '5_heart', 'Q_heart', '9_spade', '3_spade']}
# {'shinohara': ['9_club', '7_club', '6_diamond'], 'tomo': ['3_diamond', '5_spade', '6_heart', 'K_diamond', 'Q_spade', 'j1'], 'takami': ['7_diamond'], 'kobay': ['3_spade', '5_heart', '9_spade', 'K_club', 'Q_heart']}
# {'shinohara': ['7_club', '9_club'], 'tomo': ['5_spade', 'Q_spade', 'K_diamond', 'j1', '3_diamond'], 'takami': ['7_diamond'], 'kobay': ['3_spade', '5_heart', '9_spade', 'K_club', 'Q_heart']}
# {'shinohara': ['7_club', '9_club'], 'tomo': ['3_diamond', '5_spade', '7_diamond', 'K_diamond', 'Q_spade', 'j1'], 'takami': [], 'kobay': ['3_spade', '5_heart', '9_spade', 'K_club', 'Q_heart']}
# {'shinohara': ['7_club'], 'tomo': ['3_diamond', '5_spade', '7_diamond', 'K_diamond', 'Q_spade', 'j1'], 'takami': [], 'kobay': ['3_spade', '5_heart', 'K_club', 'Q_heart']}
# {'shinohara': ['7_club', 'Q_spade'], 'tomo': ['5_spade', 'j1', '3_diamond', 'K_diamond', '7_diamond'], 'kobay': ['3_spade', '5_heart', 'K_club', 'Q_heart']}
# {'shinohara': ['7_club', 'Q_spade'], 'tomo': ['5_spade', '7_diamond', 'K_diamond', 'j1'], 'kobay': ['K_club', 'Q_heart', '5_heart']}
# {'shinohara': ['Q_spade'], 'tomo': ['5_spade', '7_diamond', 'K_diamond', 'j1'], 'kobay': ['5_heart', '7_club', 'K_club', 'Q_heart']}
# {'shinohara': ['7_diamond', 'Q_spade'], 'tomo': ['j1', 'K_diamond', '5_spade'], 'kobay': ['5_heart', '7_club', 'K_club', 'Q_heart']}
# {'shinohara': ['7_diamond', 'Q_spade'], 'tomo': ['K_diamond', 'j1'], 'kobay': ['7_club', 'Q_heart', 'K_club']}
# {'shinohara': ['7_diamond'], 'tomo': ['K_diamond', 'j1'], 'kobay': ['7_club', 'K_club']}
# {'shinohara': ['7_diamond', 'K_diamond'], 'tomo': ['j1'], 'kobay': ['7_club', 'K_club']}
# {'shinohara': ['7_diamond', 'K_diamond'], 'tomo': ['7_club', 'j1'], 'kobay': ['K_club']}
# {'shinohara': ['K_diamond'], 'tomo': ['7_club', 'j1'], 'kobay': ['7_diamond', 'K_club']}
# {'shinohara': ['K_diamond', 'j1'], 'tomo': ['7_club'], 'kobay': ['7_diamond', 'K_club']}
# {'shinohara': ['K_diamond', 'j1'], 'tomo': ['7_club', 'K_club'], 'kobay': ['7_diamond']}
# {'shinohara': ['K_diamond'], 'tomo': ['7_club', 'K_club'], 'kobay': ['7_diamond', 'j1']}
# {'shinohara': ['7_club', 'K_diamond'], 'tomo': ['K_club'], 'kobay': ['7_diamond', 'j1']}
# {'shinohara': ['7_club', 'K_diamond'], 'tomo': ['7_diamond', 'K_club'], 'kobay': ['j1']}
# {'shinohara': ['K_diamond'], 'tomo': ['7_diamond', 'K_club'], 'kobay': ['7_club', 'j1']}
# {'shinohara': ['7_diamond', 'K_diamond'], 'tomo': ['K_club'], 'kobay': ['7_club', 'j1']}
# {'shinohara': ['7_diamond', 'K_diamond'], 'tomo': ['7_club', 'K_club'], 'kobay': ['j1']}
# {'shinohara': ['K_diamond'], 'tomo': ['7_club', 'K_club'], 'kobay': ['7_diamond', 'j1']}
# {'shinohara': ['7_club', 'K_diamond'], 'tomo': ['K_club'], 'kobay': ['7_diamond', 'j1']}
# {'shinohara': ['7_club', 'K_diamond'], 'tomo': ['7_diamond', 'K_club'], 'kobay': ['j1']}
# {'shinohara': ['K_diamond'], 'tomo': ['7_diamond', 'K_club'], 'kobay': ['7_club', 'j1']}
# {'shinohara': ['7_diamond', 'K_diamond'], 'tomo': ['K_club'], 'kobay': ['7_club', 'j1']}
# {'shinohara': ['7_diamond', 'K_diamond'], 'tomo': ['7_club', 'K_club'], 'kobay': ['j1']}
# {'shinohara': ['7_diamond'], 'tomo': ['7_club', 'K_club'], 'kobay': ['K_diamond', 'j1']}
# {'shinohara': ['7_diamond', 'K_club'], 'tomo': ['7_club'], 'kobay': ['K_diamond', 'j1']}
# {'shinohara': ['7_diamond', 'K_club'], 'tomo': ['7_club', 'K_diamond'], 'kobay': ['j1']}
# {'shinohara': ['K_club'], 'tomo': ['7_club', 'K_diamond'], 'kobay': ['7_diamond', 'j1']}
# {'shinohara': ['7_club', 'K_club'], 'tomo': ['K_diamond'], 'kobay': ['7_diamond', 'j1']}
# {'shinohara': ['7_club', 'K_club'], 'tomo': ['K_diamond', 'j1'], 'kobay': ['7_diamond']}
# {'shinohara': ['K_club'], 'tomo': ['K_diamond', 'j1'], 'kobay': []}
# {'shinohara': ['K_club', 'j1'], 'tomo': ['K_diamond']}
# {'shinohara': ['K_club'], 'tomo': ['K_diamond', 'j1']}
# {'shinohara': ['K_club', 'j1'], 'tomo': ['K_diamond']}
# {'shinohara': ['K_club'], 'tomo': ['K_diamond', 'j1']}
# {'shinohara': [], 'tomo': ['j1']}
# youの長さがゼロです
# ['takami', 'kobay', 'shinohara', 'tomo']
#
#
#
# 18回
#
#
#
# 順位
# 第1位:takami
# 第2位:kobay
# 第3位:shinohara
# 第4位:tomo
